# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql import types

# %%
spark = SparkSession.builder.master("local[*]").getOrCreate()

# %%
df = spark.read\
	.option("header", "true")\
	.parquet('fhvhv_tripdata_2021-01.parquet')

# %%
df = df.repartition(24)

# %%
df.write.parquet("fhvhv/2021/01")
# Out:
# 26/04/10 22:17:09 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/04/10 22:17:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/04/10 22:17:14 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/04/10 22:17:18 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers

# %%
spark.stop()
